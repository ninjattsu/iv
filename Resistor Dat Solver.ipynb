# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator,FormatStrFormatter,MaxNLocator

# %%
from io import StringIO

temp=u"""VD	ID	ID2	ID3	ID4	ID5	ID6	ID7	ID8	
0.00000000E+000	2.36900000E-007	2.91790000E-007	3.83090000E-007	3.45000000E-007	1.24150000E-006	1.67700000E-006	1.97300000E-006	1.98850000E-006	
5.00000000E-002	5.09250000E-005	9.71850000E-005	1.47100000E-004	1.89850000E-004	2.27250000E-004	2.58400000E-004	2.85800000E-004	3.16200000E-004	
1.00000000E-001	8.35280000E-005	1.66550000E-004	2.65150000E-004	3.53350000E-004	4.30510000E-004	4.94810000E-004	5.51100000E-004	6.12650000E-004"""
#after testing replace StringIO(temp) to filename
df = pd.read_csv("STEP15_MOSFET_ID_VD_100um_x_05um.dat", delim_whitespace = True, header=37,
                 engine='python')

names = ['VD', 'ID', 'ID2', 'ID3', 'ID4','ID5','ID6','ID7','ID8']
df.columns = names

print(df)
# Out:
#                  VD               ID              ID2              ID3  \
# 0   3.50000000E-001  1.71500000E-004  3.16350000E-004  5.42310000E-004
# 1   4.00000000E-001  1.86400000E-004  3.35750000E-004  5.68390000E-004
# 2   4.50000000E-001  2.02900000E-004  3.55050000E-004  5.93220000E-004
# 3   5.00000000E-001  2.19000000E-004  3.73750000E-004  6.16400000E-004
# 4   5.50000000E-001  2.35350000E-004  3.92960000E-004  6.39410000E-004
# ..              ...              ...              ...              ...
# 90  4.85000000E+000  2.93210000E-003  3.06700000E-003  3.26000000E-003
# 91  4.90000000E+000  2.97400000E-003  3.10800000E-003  3.30010000E-003
# 92  4.95000000E+000  3.01550000E-003  3.14950000E-003  3.33950000E-003
# 93  5.00000000E+000  3.05900000E-003  3.19150000E-003  3.38010000E-003
# 94             TEST         RESULTS:           MOSFET       12/04/2023
#
#                 ID4       ID5       ID6       ID7       ID8
# 0   8.17270000E-004  0.001113  0.001375  0.001608  0.001849
# 1   8.57500000E-004  0.001182  0.001484  0.001759  0.002039
# 2   8.91860000E-004  0.001238  0.001574  0.001888  0.002210
# 3   9.22260000E-004  0.001282  0.001646  0.001998  0.002360
# 4   9.49920000E-004  0.001319  0.001703  0.002087  0.002491
# ..              ...       ...       ...       ...       ...
# 90  3.52550000E-003  0.003874  0.004279  0.004764  0.005406
# 91  3.56150000E-003  0.003910  0.004307  0.004807  0.005441
# 92  3.59900000E-003  0.003944  0.004339  0.004855  0.005476
# 93  3.63460000E-003  0.003981  0.004369  0.004912  0.005511
# 94         23:44:55       NaN       NaN       NaN       NaN
#
# [95 rows x 9 columns]

# %%
df
# Out:
#     3.50000000E-001  1.71500000E-004  3.16350000E-004  5.42310000E-004  \
# 0   4.00000000E-001  1.86400000E-004  3.35750000E-004  5.68390000E-004
# 1   4.50000000E-001  2.02900000E-004  3.55050000E-004  5.93220000E-004
# 2   5.00000000E-001  2.19000000E-004  3.73750000E-004  6.16400000E-004
# 3   5.50000000E-001  2.35350000E-004  3.92960000E-004  6.39410000E-004
# 4   6.00000000E-001  2.52650000E-004  4.12600000E-004  6.61910000E-004
# ..              ...              ...              ...              ...
# 89  4.85000000E+000  2.93210000E-003  3.06700000E-003  3.26000000E-003
# 90  4.90000000E+000  2.97400000E-003  3.10800000E-003  3.30010000E-003
# 91  4.95000000E+000  3.01550000E-003  3.14950000E-003  3.33950000E-003
# 92  5.00000000E+000  3.05900000E-003  3.19150000E-003  3.38010000E-003
# 93             TEST         RESULTS:           MOSFET       12/04/2023
#
#     8.17270000E-004  1.11300000E-003  1.37450000E-003  1.60800000E-003  \
# 0   8.57500000E-004         0.001182         0.001484         0.001759
# 1   8.91860000E-004         0.001238         0.001574         0.001888
# 2   9.22260000E-004         0.001282         0.001646         0.001998
# 3   9.49920000E-004         0.001319         0.001703         0.002087
# 4   9.76200000E-004         0.001353         0.001750         0.002161
# ..              ...              ...              ...              ...
# 89  3.52550000E-003         0.003874         0.004279         0.004764
# 90  3.56150000E-003         0.003910         0.004307         0.004807
# 91  3.59900000E-003         0.003944         0.004339         0.004855
# 92  3.63460000E-003         0.003981         0.004369         0.004912
# 93         23:44:55              NaN              NaN              NaN
#
#     1.84900000E-003
# 0          0.002039
# 1          0.002210
# 2          0.002360
# 3          0.002491
# 4          0.002602
# ..              ...
# 89         0.005406
# 90         0.005441
# 91         0.005476
# 92         0.005511
# 93              NaN
#
# [94 rows x 9 columns]

# %% [markdown]
# ### Plotter for ECE220 Resistance Values
# Edit the functions to load the data.

# %%
df = pd.read_excel('TLM_IV_30um.xlsx') #converted from .dat file to .xlsx file

# %%
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.family'] = 'Arial'

plt.figure(figsize=(3.54,3.54), dpi=600)

plt.xlabel('Voltage (V)', fontsize=10)
plt.ylabel('Current (Amps)', fontsize=10)
plt.title('TL Measurement at 30um Separation Before Sintering', fontsize=6)

plt.plot(df[df.columns[0]],df[df.columns[1]],linewidth=0.5,zorder=1, label = "", color = 'blue')

# %%
#DONE Make a resistance calculator using two points in that graph (or more), save to a csv, then plot said csv below
# V/I = R
checkpoint = []
data_list = ['TLM_IV_sinter_10um.xlsx', 'TLM_IV_sinter_30um.xlsx', 'TLM_IV_sinter_50um.xlsx', 'TLM_IV_sinter_70um.xlsx', 'TLM_IV_sinter_90um.xlsx']

for i in data_list:
    df = pd.read_excel(i)
    R = df[df.columns[0]] / df[df.columns[1]]
    checkpoint.append(R)

# %%
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.family'] = 'Arial'

plt.figure(figsize=(3.54,3.54), dpi=600)

plt.ylabel('Resistance (Ohm)', fontsize=10)
plt.xlabel('Measurement Distance (m)', fontsize=10)
plt.title('TLL Measurement of Resistance at Different Separations After Sintering', fontsize=6)
plt.xticks(np.arange(5), ('10µ', '30µ', '50µ', '70µ', '90µ'))

plt.scatter(np.arange(5), [i[60] for i in checkpoint], linewidth=0.5,zorder=1, label = "", color = 'purple')
